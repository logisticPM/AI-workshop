# %% [markdown]
# <a href="https://colab.research.google.com/github/logisticPM/AI-workshop/blob/main/agent_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qU transformers bitsandbytes "mcp[cli]" httpx openai googlesearch-python beautifulsoup4 requests nest_asyncio
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 734.3/734.3 kB 26.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 65.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 57.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...

# %%
# Apply nest_asyncio to allow nested use of asyncio.run in notebooks.
import nest_asyncio
nest_asyncio.apply()

# %%
from google.colab import files
files.upload()  # 选择 agent_colab_multi.py 和 weather_mcp_server.py
# Out:
#      <input type="file" id="files-2b1b695b-75e2-4283-a114-d7bd2e2801ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2b1b695b-75e2-4283-a114-d7bd2e2801ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python agent_colab_multi.py weather_mcp_server.py
# Out:
# Please enter your OpenRouter API Key (input will be hidden)
# OpenRouter API Key (sk-...):
# ...
# Please enter the research topic: seattle's weather for tomorrow
# Supervisor: Planning report structure...
# Supervisor: Planned sections: ['Current Weather Conditions in Seattle', "Tomorrow's Forecast Overview", 'Temperature and Precipitation Predictions', 'Wind and Atmospheric Conditions', 'Weather Advisories and Recommendations']
# Researcher: Writing section [Current Weather Conditions in Seattle] ...
# Detected weather-related section [Current Weather Conditions in Seattle]. Available tools: 1) get_alerts (state) 2) get_forecast (latitude/longitude)
# Please select the tool to use (1=alerts, 2=forecast): 2
# Enter latitude (e.g. 37.77): 47.62
# Enter longitude (e.g. -122.42): -122.34
# Researcher: Writing section [Tomorrow's Forecast Overview] ...
# ...

# %%
# !python agent_colab_workflow.py
# Out:
# Please enter your OpenRouter API Key (input will be hidden)
# OpenRouter API Key (sk-...):
# Please enter the research topic: seattle's weather for tomorrow
# Planning report structure...
# ...
